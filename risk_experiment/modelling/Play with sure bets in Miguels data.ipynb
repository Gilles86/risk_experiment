# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/data/risk_precision/magRiskData2.csv')
df['presentation'] = df['exptype'].astype(int).map({1:'coins', 2:'symbolic', 3:'coins'})
df['type'] = df['exptype'].map({1:'magnitude', 2:'risk', 3:'risk'})
df.drop(columns='exptype', inplace=True)

df = df.rename(columns={"subcode":'subject'})

df = df.set_index(['subject', 'run', 'type', 'presentation'])

df['choice'] = df.choice.map({-2:np.nan, 2:np.nan, -1:1, 1:0})
df['frac'] = df['prob_bet'] / df['sure_bet']
df['log(frac)'] = np.log(df['frac'])

# %%
d = df.xs('risk', 0, 'type').xs('coins', 0, 'presentation')

df = df[~df['choice'].isnull()]

# %%
import seaborn as sns

# %%
import statsmodels.api as sm

# %%
subject = 2

# %%
def get_prob_pars(d):
    X = np.hstack((np.ones((len(d), 1)), d['log(frac)'].values[:, np.newaxis]))
    model = sm.Probit(d['choice'], X)
    
    try:
        return model.fit().params
    except Exception as e:
        return pd.Series([])

# %%
pars = df[~df['choice'].isnull()].groupby(['subject', 'type', 'presentation']).apply(get_prob_pars).unstack()
pars
# Out:
# Optimization terminated successfully.
#          Current function value: 0.217972
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.307563
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.155554
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.220368
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.250357
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.158654
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.275657
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.325057
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.306069
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.300431
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.358306
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.258218
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.289403
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.493803
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.489083
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.268272
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.579430
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588048
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.224881
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.342111
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428279
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.217784
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.363225
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.254904
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.310537
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.412102
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.358884
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.309627
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.323281
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.143166
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.203516
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.318421
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.245527
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.164953
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.542162
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.482663
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.248605
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.324437
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.138152
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.278392
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.360728
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.221982
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.187706
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.366651
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.304166
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.209139
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.373530
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.187339
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.279644
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.337174
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.252943
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.236079
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.285891
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.135305
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.342833
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.268350
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.157250
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.339917
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.254072
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.223966
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.142382
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.264444
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.147787
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.194698
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.297055
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.295795
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.127559
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.384378
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.247025
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.321211
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.360946
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.185097
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.170883
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.454329
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.328648
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.192604
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.382655
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.360182
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.226495
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422508
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.350804
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.406239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.447521
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518950
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.344312
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.353126
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.340536
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.348228
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.376308
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.163368
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.165768
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.425739
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.407253
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.270225
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.488563
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462128
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.214706
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.462048
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.423023
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.266519
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.287442
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.245744
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.172427
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.424510
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.179734
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162900
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.428030
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.233961
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.106510
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.428784
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478038
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.185901
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.463514
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.240648
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.299885
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.451512
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.556289
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.199382
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.372130
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.250495
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.266067
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.381463
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.166847
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.208010
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.423057
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.173383
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.147083
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.319967
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.358986
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.279216
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.217758
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.162635
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.248626
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.684079
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690103
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.145388
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.424322
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.363353
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.225878
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.288101
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.153770
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.214728
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.335053
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.170843
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.235761
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.370723
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.433614
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.277911
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.366215
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.166806
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.272773
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.279268
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.406797
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.253949
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.544907
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.445107
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.317982
#          Iterations 6
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.017567
#          Iterations: 35
# Optimization terminated successfully.
#          Current function value: 0.134007
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.335690
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.183728
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.241711
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.420166
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.287918
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.159902
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.316050
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.168315
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.224557
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.372714
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.385046
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.198616
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.361888
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.292499
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.501822
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.178275
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.148533
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.145364
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.318364
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.199867
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.247979
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.419940
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.326372
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.243710
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.080530
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.224984
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.235862
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.362148
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.239655
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.248499
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.178423
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.339308
#          Iterations 7
# /Users/gdehol/miniconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                    const        x1
# subject type      presentation
# 1       magnitude coins        -0.006413  3.489288
#         risk      coins        -2.723712  3.531554
#                   symbolic     -4.220355  7.573739
# 2       magnitude coins        -0.205324  3.300072
#         risk      coins        -2.455080  4.567609
# ...                                  ...       ...
# 63      risk      coins        -2.877527  3.003708
#                   symbolic     -4.847453  4.905931
# 64      magnitude coins         0.180339  2.856383
#         risk      coins        -4.950594  3.390953
#                   symbolic     -2.730623  1.776081
#
# [191 rows x 2 columns]

# %%
fac = sns.swarmplot('type', 'const', 'presentation', data=pars.reset_index(), dodge=True)
fac.set(ylim=(5, -10))
# Out:
# [(5, -10)]

# %%
fac = sns.swarmplot('type', 'x1', 'presentation', data=pars.reset_index(), dodge=True)
fac.set(ylim=(0, 10))
# Out:
# [(0, 10)]

# %%
fac = sns.lmplot('const', 'x1', pars.xs('risk', 0, 'type').reset_index(), 'presentation')
fac.set(xlim=(-15, 5), ylim=(-5, 15))

# %%
import scipy.stats as ss

# %%
p = pars.iloc[0]

# %%
p.dot(np.array([[1, 2], [3, 4]]).T)
# Out:
# array([ 6.97216302, 13.93791287])

# %%
pars.xs('risk',0,'type').xs('coins', 0, 'presentation').mean()
# Out:
# const   -2.493546
# x1       2.863674
# dtype: float64

# %%
pars.xs('risk',0,'type').xs('coins', 0, 'presentation').std()
# Out:
# const    0.928975
# x1       1.318474
# dtype: float64

# %%
sns.distplot(pars.xs('risk',0,'type').xs('coins', 0, 'presentation')['const'])
sns.distplot(pars.xs('risk',0,'type').xs('coins', 0, 'presentation')['x1'])

# %%
def plot_pars(pars, x_range=(-1, 2), *args, **kwargs):
    
    x = np.linspace(x_range[0], x_range[1], 100)
    
    X = np.hstack((np.ones((100, 1)), x[:, np.newaxis]))
    
    y_ = pars.dot(X.T)
    
    y = ss.norm.cdf(y_)
    
    return plt.plot(x, y, *args, **kwargs)

# %%
for ix, row in pars.xs('magnitude',0,'type').iterrows():
    plot_pars(row)

# %%
h = np.arange(9)
fractions = 2**(h/4)

# %%
fractions
# Out:
# array([1.        , 1.18920712, 1.41421356, 1.68179283, 2.        ,
#        2.37841423, 2.82842712, 3.36358566, 4.        ])

# %%
h = np.arange(1, 9)
fractions = 2**(h/4)

# %%
for ix, row in pars.xs('risk',0,'type').xs('coins', 0, 'presentation').iterrows():
    plot_pars(row, alpha=0.15, c='k')
    
# plt.axvline(np.log(1./.55), c='r')
plt.xticks(np.log(fractions), [f'h = {h}' for h in range(1, 9)], rotation='vertical')



plt.xlim(np.log(fractions[0]) - .1, np.log(fractions[-1]) + .1)
plt.xlabel('Expected payoff(risky) / Expected payoff(sure)')
sns.despine()

# %%
df['round(frac)'] = np.round(df['frac'], 2)


tmp = df.xs('coins', 0, 'presentation').xs('risk', 0, 'type').groupby(['round(frac)', 'subject']).mean()

sns.swarmplot('round(frac)', 'choice', data=tmp.reset_index())

sns.catplot('round(frac)', 'choice', data=tmp.reset_index(), kind='bar', aspect=2.)
# Out:
# /Users/gdehol/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['round(frac)'] = np.round(df['frac'], 2)


tmp = df.xs('coins', 0, 'presentation').xs('risk', 0, 'type').groupby(['round(frac)', 'subject']).size().to_frame('n')

sns.swarmplot('round(frac)', 'n', data=tmp.reset_index())

sns.catplot('round(frac)', 'n', data=tmp.reset_index(), kind='bar', aspect=2.)
# Out:
# /Users/gdehol/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.xs('coins', 0, 'presentation').xs('risk', 0, 'type').groupby(['sure_bet', 'prob_bet']).size()
# Out:
# sure_bet  prob_bet
# 5         6           391
#           7           382
#           8           290
#           10          258
#           12          258
#           14          324
#           17          288
#           20          305
# 7         8           456
#           9           115
#           10          297
#           12          276
#           14          269
#           17          265
#           20          300
#           24          265
#           28          269
# 10        11          124
#           12          422
#           14          273
#           17          258
#           20          326
#           24          262
#           28          273
#           34          304
#           40          275
# 14        15          143
#           16          147
#           17          277
#           20          273
#           24          302
#           28          304
#           33          255
#           40          250
#           47          287
#           56          291
# 20        21          140
#           22          146
#           24          279
#           28          280
#           34          268
#           40          298
#           48          254
#           57          287
#           67          290
#           80          305
# 28        29          147
#           30          119
#           33          308
#           40          281
#           47          283
#           56          275
#           67          284
#           79          282
#           94          281
#           112         289
# dtype: int64

# %%
h = np.arange(9)
fractions = 2**(h/4)

# %%
d = df.xs('risk',0,'type').xs('coins', 0, 'presentation')

# %%
d['nearest_fraction'] = fractions[np.abs(d['frac'].values[:, np.newaxis] - fractions[np.newaxis, :]).argmin(1)]

# %%
d['nearest_fraction'] = d['nearest_fraction'].map(dict(zip(fractions, ['2^{}/4'.format(n) for n in range(9)])))

# %%
sns.catplot('nearest_fraction', 'choice', data=d.groupby(['subject', 'nearest_fraction', 'sure_bet']).mean().reset_index(), 
            hue='sure_bet', kind='point')

# %%
tmp = d.groupby(['subject', 'nearest_fraction', 'sure_bet']).mean()['choice']

tmp = tmp.map(lambda x: min(x, 1-x)).to_frame('smallest_proportion')

sns.catplot('nearest_fraction', 'smallest_proportion', 
            data=tmp.reset_index(), 
            hue='sure_bet', kind='point', aspect=2.)

# %%
tmp = d.groupby(['subject', 'nearest_fraction', 'sure_bet']).mean()['choice']

tmp = tmp.map(lambda x: min(x, 1-x)).to_frame('smallest_proportion')

sns.catplot('nearest_fraction', 'smallest_proportion', 
            data=tmp.groupby(['subject', 'nearest_fraction']).mean().reset_index(), kind='point', aspect=2.)

# %%
tmp.head()
# Out:
#                                    smallest_proportion
# subject nearest_fraction sure_bet
# 1       2^0/4            14                        0.0
#                          20                        0.0
#                          28                        0.0
#         2^1/4            5                         0.0
#                          7                         0.1

# %%
sns.distplot(tmp.groupby(['subject']).mean())

tmp.groupby(['subject']).mean().mean(), tmp.groupby(['subject']).max().mean()
# Out:
# (smallest_proportion    0.117948
#  dtype: float64,
#  smallest_proportion    0.482738
#  dtype: float64)

# %%
ix = pd.IndexSlice
sns.distplot(tmp.loc[ix[:, ['2^3/4', '2^4/4', '2^5/4', '2^6/4']], :].groupby(['subject']).mean())

tmp.loc[ix[:, ['2^3/4', '2^4/4', '2^5/4', '2^6/4']], :].groupby(['subject']).mean().mean(), tmp.loc[ix[:, ['2^3/4', '2^4/4', '2^5/4', '2^6/4']], :].groupby(['subject']).max().mean()
# Out:
# (smallest_proportion    0.161313
#  dtype: float64,
#  smallest_proportion    0.473909
#  dtype: float64)

# %%
ix = pd.IndexSlice
sns.distplot(tmp.loc[ix[:, ['2^4/4', '2^5/4', '2^6/4', '2^7/4']], :].groupby(['subject']).mean())

tmp.loc[ix[:, ['2^4/4', '2^5/4', '2^6/4', '2^7/4']], :].groupby(['subject']).mean().mean(), tmp.loc[ix[:, ['2^4/4', '2^5/4', '2^6/4', '2^7/4']], :].groupby(['subject']).max().mean()
# Out:
# (smallest_proportion    0.159538
#  dtype: float64,
#  smallest_proportion    0.471825
#  dtype: float64)

# %%
tmp = d.groupby(['subject', 'nearest_fraction', 'sure_bet']).mean()['choice']

tmp = tmp.map(lambda x: min(x, 1-x)).to_frame('smallest_proportion')

sns.catplot('nearest_fraction', 'smallest_proportion', 
            data=tmp.groupby(['subject', 'nearest_fraction']).mean().reset_index(), kind='swarm', aspect=2.)
