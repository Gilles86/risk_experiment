# %%
import nibabel as nib

# %%
nib.load('/data/ds-risk_bids2/sub-02/ses-7t2/func/sub-02_ses-7t2_task-task_run-1_bold.nii.gz').header.get_xyzt_units()
# Out:
# ('mm', 'msec')

# %%
nib.load('/data/ds-risk_bids2/sub-02/ses-7t2/func/sub-02_ses-7t2_task-task_run-1_bold.nii.gz').header

# %%
# !ls /data/ds-risk_bids2/sub-02/ses-7t2/func
# Out:
# sub-02_ses-7t2_task-task_run-1_bold.json
# sub-02_ses-7t2_task-task_run-1_bold.nii.gz
# sub-02_ses-7t2_task-task_run-1_events.tsv
# sub-02_ses-7t2_task-task_run-2_bold.json
# sub-02_ses-7t2_task-task_run-2_bold.nii.gz
# sub-02_ses-7t2_task-task_run-2_events.tsv
# sub-02_ses-7t2_task-task_run-3_bold.json
# sub-02_ses-7t2_task-task_run-3_bold.nii.gz
# sub-02_ses-7t2_task-task_run-3_events.tsv
# sub-02_ses-7t2_task-task_run-4_bold.json
# sub-02_ses-7t2_task-task_run-4_bold.nii.gz
# sub-02_ses-7t2_task-task_run-4_events.tsv
# sub-02_ses-7t2_task-task_run-5_bold.json
# sub-02_ses-7t2_task-task_run-5_bold.nii.gz
# sub-02_ses-7t2_task-task_run-5_events.tsv
# sub-02_ses-7t2_task-task_run-6_bold.json
# sub-02_ses-7t2_task-task_run-6_bold.nii.gz
# sub-02_ses-7t2_task-task_run-6_events.tsv
# sub-02_ses-7t2_task-task_run-7_bold.json
# sub-02_ses-7t2_task-task_run-7_bold.nii.gz
# sub-02_ses-7t2_task-task_run-7_events.tsv
# sub-02_ses-7t2_task-task_run-8_bold.json
# ...
