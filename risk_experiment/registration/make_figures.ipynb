# %%
from nilearn import image, plotting
import os.path as op

bids_folder = '/data/ds-risk'

# %%
t1w = op.join(bids_folder, 'derivatives', 'registration', 'group', 'group_space-MNI152NLin2009cAsym_field-7t_T1w.nii.gz')
t2starw = op.join(bids_folder, 'derivatives', 'registration', 'group', 'group_space-MNI152NLin2009cAsym_field-7t_T2starw.nii.gz')

# %%
plotting.plot_anat(t1w, vmin=0, vmax=5, draw_cross=False, cut_coords=(-10, -17, 11))

# %%
plotting.plot_anat(t2starw, vmin=0, vmax=3, draw_cross=False, cut_coords=(-10, -17, 11))
