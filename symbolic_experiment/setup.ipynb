# %%
import numpy as np

import pandas as pd

# %%
from risk_experiment.utils.data import get_all_behavior

# %%
# Length trial

jitter1 = np.mean([4,5,6])


phase_durations = [.25, .3, .3, .5, .6, jitter1, .3, .3, .6, 2.5, .5]

np.sum(phase_durations)


256 * 11
# Out:
# 2816

# %%
np.sum(phase_durations)
# Out:
# 11.149999999999999

# %%
import numpy as np
import pandas as pd
# Sample randomly in log space between log(5) and log(28):

n = 10000
safe_payoffs = np.exp(np.random.uniform(low=np.log(5), high=np.log(28), size=n))
fractions = np.random.uniform(low=1, high=4, size=n)
risk_payoffs = safe_payoffs * fractions

# Create a dataframe with the payoffs
payoffs = pd.DataFrame({'safe_payoff': safe_payoffs, 'risk_payoff': risk_payoffs})

payoffs
# Out:
#       safe_payoff  risk_payoff
# 0       25.093274    28.263784
# 1       10.560656    11.377478
# 2        8.837264    14.442975
# 3        5.376368    16.083117
# 4       10.463738    21.786182
# ...           ...          ...
# 9995    25.092165    38.987091
# 9996    21.701058    26.702233
# 9997    16.023206    27.428196
# 9998    22.354127    52.383101
# 9999     5.764170    19.888448
#
# [10000 rows x 2 columns]

# %%
print(payoffs.describe())

expected_payoff = .5 * payoffs['safe_payoff'] + .55 * .5 * payoffs['risk_payoff']

expected_payoff.describe()
# Out:
#         safe_payoff   risk_payoff
# count  10000.000000  10000.000000
# mean      13.296156     33.263375
# std        6.459115     20.624455
# min        5.002021      5.119700
# 25%        7.662312     17.896284
# 50%       11.766971     27.633006
# 75%       18.107503     43.678010
# max       27.999590    110.437100
# count    10000.000000
# mean        15.795506
# std          8.441102
# min          3.946229
# 25%          8.925132
# 50%         13.678672
# 75%         21.012552
# max         44.307781
# dtype: float64

# %%
log
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 log
#
# NameError: name 'log' is not defined

# %%
df = get_all_behavior(bids_folder='/data/ds-risk')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = get_all_behavior(bids_folder='/data/ds-risk')
#
# NameError: name 'get_all_behavior' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns
sns.histplot(df['n_safe'])
sns.histplot(df['n_risky'])
# Out:
# <Axes: xlabel='n_safe', ylabel='Count'>

# %%
sns.distplot(df['frac'])
# Out:
# /var/folders/d4/cpqhwlbn301clph1qk64k01nmjkty3/T/ipykernel_22650/87563205.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['frac'])
# <Axes: xlabel='frac', ylabel='Density'>

# %%
import matplotlib.pyplot as plt
sns.lmplot(x='log(risky/safe)', y='chose_risky', data=df.reset_index(), hue='subject', logistic=True)


plt.axvline(np.log(1/.55))

# %%
def get_symbolic_trials(n=128):

    n_safe = np.random.rand(n) * 23
    n_safe += 5

    frac = np.random.rand(n)*3 + 1

    n_risky = n_safe * frac

    return pd.DataFrame({'n_safe':np.round(n_safe,2), 'n_risky':np.round(n_risky, 2)})

# %%
sns.scatterplot(data=get_symbolic_trials(), x='n_safe', y='n_risky')
# Out:
# <Axes: xlabel='n_safe', ylabel='n_risky'>

# %%
get_symbolic_trials()
# Out:
#      n_safe  n_risky
# 0     14.79    52.61
# 1      5.77    22.69
# 2     27.37    57.73
# 3     24.78    89.99
# 4     10.90    40.82
# ..      ...      ...
# 123    5.22     6.02
# 124    6.58    24.92
# 125   20.20    29.72
# 126   11.74    42.57
# 127   21.67    76.24
#
# [128 rows x 2 columns]
